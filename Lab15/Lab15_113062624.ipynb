# %%
# !git clone https://github.com/ntasfi/PyGame-Learning-Environment
# %cd PyGame-Learning-Environment
# !pip install -e .
# !pip install pygame
# Out:
# Cloning into 'PyGame-Learning-Environment'...
# remote: Enumerating objects: 1118, done.
# remote: Total 1118 (delta 0), reused 0 (delta 0), pack-reused 1118 (from 1)
# Receiving objects: 100% (1118/1118), 8.06 MiB | 61.10 MiB/s, done.
# Resolving deltas: 100% (592/592), done.
# /content/PyGame-Learning-Environment
# Obtaining file:///content/PyGame-Learning-Environment
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ple==0.0.1) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from ple==0.0.1) (11.0.0)
# Installing collected packages: ple
#   Running setup.py develop for ple
# Successfully installed ple-0.0.1
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (2.6.1)

# %%
import numpy as np
import matplotlib.pyplot as plt
import moviepy.editor as mpy
import skimage.transform
from IPython.display import Image, display

import tensorflow as tf
import tensorflow_probability as tfp
import tensorflow.keras.losses as kls
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/sliders.py:61: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if event.key is 'enter':

# %%
gpus = tf.config.list_physical_devices("GPU")
if gpus:
    try:
        # Restrict TensorFlow to only use the fourth GPU
        tf.config.set_visible_devices(gpus[0], 'GPU')

        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)

        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)

# %%
import os
os.environ["SDL_VIDEODRIVER"] = "dummy"  # this line make pop-out window not appear
from ple.games.flappybird import FlappyBird
from ple import PLE

game = FlappyBird()
env = PLE(game, fps=30, display_screen=False)  # environment interface to game
env.reset_game()

test_game = FlappyBird()
test_env = PLE(test_game, fps=30, display_screen=False)
test_env.reset_game()
# Out:
# couldn't import doomish
# Couldn't import doom

# %%
path = './movie_f'
if not os.path.exists(path):
    os.makedirs(path)

# %%
hparas = {
    'image_size': 84,
    'num_stack': 4,
    'action_dim': len(env.getActionSet()),
    'hidden_size': 256,
    'lr': 0.0001,
    'gamma': 0.99,
    'lambda': 0.95,
    'clip_val': 0.2,
    'ppo_epochs': 8,
    'test_epochs': 1,
    'num_steps': 512,
    'mini_batch_size': 64,
    'target_reward': 200,
    'max_episode': 30000,
}

# %%
# Please do not modify this method
def make_anim(images, fps=60, true_image=False):
    duration = len(images) / fps

    def make_frame(t):
        try:
            x = images[int(len(images) / duration * t)]
        except:
            x = images[-1]

        if true_image:
            return x.astype(np.uint8)
        else:
            return ((x + 1) / 2 * 255).astype(np.uint8)

    clip = mpy.VideoClip(make_frame, duration=duration)
    clip.fps = fps

    return clip

# %%
def preprocess_screen(screen):
    screen = skimage.transform.rotate(screen, -90, resize=True)
    screen = screen[:400, :]
    screen = skimage.transform.resize(screen, [hparas['image_size'], hparas['image_size'], 1])
    return screen.astype(np.float32)

def frames_to_state(input_frames):
    if(len(input_frames) == 1):
        state = np.concatenate(input_frames*4, axis=-1)
    elif(len(input_frames) == 2):
        state = np.concatenate(input_frames[0:1]*2 + input_frames[1:]*2, axis=-1)
    elif(len(input_frames) == 3):
        state = np.concatenate(input_frames + input_frames[2:], axis=-1)
    else:
        state = np.concatenate(input_frames[-4:], axis=-1)

    return state

# %%
class ActorCriticNetwork(tf.keras.Model):
    def __init__(self, hparas):
        super().__init__()

        self.feature_extractor = tf.keras.Sequential([
          # Convolutional Layers
          tf.keras.layers.Conv2D(filters=32, kernel_size=8, strides=4),
          tf.keras.layers.ReLU(),
          tf.keras.layers.Conv2D(filters=64, kernel_size=4, strides=2),
          tf.keras.layers.ReLU(),
          tf.keras.layers.Conv2D(filters=64, kernel_size=3, strides=1),
          tf.keras.layers.ReLU(),
          # Embedding Layers
          tf.keras.layers.Flatten(),
          tf.keras.layers.Dense(hparas['hidden_size']),
          tf.keras.layers.ReLU(),
        ])

        # Actor Network
        self.actor = tf.keras.layers.Dense(hparas['action_dim'], activation='softmax')
        # Critic Network
        self.critic = tf.keras.layers.Dense(1, activation = None)

    def call(self, input):
        x = self.feature_extractor(input)
        action_logits = self.actor(x)
        value = self.critic(x)
        return action_logits, value

# %%
class Agent():
    def __init__(self, hparas):
        self.gamma = hparas['gamma']
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=hparas['lr'])
        self.actor_critic = ActorCriticNetwork(hparas)
        self.clip_pram = hparas['clip_val']

    def ppo_iter(self, mini_batch_size, states, actions, log_probs, returns, advantage):
        batch_size = states.shape[0]
        for _ in range(batch_size // mini_batch_size):
            rand_ids = tf.convert_to_tensor(np.random.randint(0, batch_size, mini_batch_size), dtype=tf.int32)
            yield tf.gather(states, rand_ids), tf.gather(actions, rand_ids), tf.gather(log_probs, rand_ids), \
             tf.gather(returns, rand_ids), tf.gather(advantage, rand_ids)

    def ppo_update(self, ppo_epochs, mini_batch_size, states, actions, log_probs, discount_rewards, advantages):
        total_actor_loss = 0
        total_critic_loss = 0
        for _ in range(ppo_epochs):
            for state, action, old_log_probs, reward, advantage in self.ppo_iter(mini_batch_size, states, actions, log_probs, discount_rewards, advantages):
                reward = tf.expand_dims(reward, axis=-1)

                with tf.GradientTape() as tape:
                    prob, value = self.actor_critic(state, training=True)
                    dist = tfp.distributions.Categorical(probs=prob, dtype=tf.float32)
                    entropy = tf.math.reduce_mean(dist.entropy())
                    new_log_probs = dist.log_prob(action)

                    # PPO ratio
                    ratio = tf.math.exp(new_log_probs - old_log_probs)
                    surr1 = ratio * advantage
                    surr2 = tf.clip_by_value(ratio, 1.0 - self.clip_pram, 1.0 + self.clip_pram) * advantage

                    actor_loss = tf.math.negative(tf.math.reduce_mean(tf.math.minimum(surr1, surr2))) - 0.1 * entropy
                    #//
                    critic_loss = 0.5 * tf.math.reduce_mean(tf.math.squared_difference(reward, value))

                    total_loss = actor_loss + critic_loss

                # single optimizer
                grads = tape.gradient(total_loss, self.actor_critic.trainable_variables)
                self.optimizer.apply_gradients(zip(grads, self.actor_critic.trainable_variables))

                total_actor_loss += actor_loss
                total_critic_loss += critic_loss
        return total_actor_loss, total_critic_loss

# %%
# https://arxiv.org/pdf/1506.02438.pdf
# Equation 16
def compute_gae(rewards, masks, values, gamma, LAMBDA):
    gae = 0
    returns = []
    for i in reversed(range(len(rewards))):
        delta = rewards[i] + gamma * values[i + 1] * masks[i] - values[i]
        gae = delta + gamma * LAMBDA * masks[i] * gae
        returns.append(gae + values[i])

    returns.reverse()
    return returns

# %% [markdown]
# # Testing Environment

# %%
def test_reward(test_env, agent):
    total_reward = 0
    # Reset the environment
    test_env.reset_game()
    input_frames = [preprocess_screen(test_env.getScreenGrayscale())]

    while not test_env.game_over():

        state = frames_to_state(input_frames)
        state = tf.expand_dims(state, axis=0)
        prob, value = agent.actor_critic(state)

        action = np.argmax(prob[0].numpy())
        reward = test_env.act(test_env.getActionSet()[action])
        total_reward += reward

        input_frames.append(preprocess_screen(test_env.getScreenGrayscale()))

    return total_reward

# %% [markdown]
# # Training

# %%
agent = Agent(hparas)
max_episode = hparas['max_episode']
test_per_n_episode = 10
force_save_per_n_episode = 1000
early_stop_reward = 10

start_s = 0
best_reward = -5.0

checkpoint = tf.train.Checkpoint(
    actor_critic = agent.actor_critic,
    optimizer = agent.optimizer,
)

# Load from old checkpoint
# checkpoint.restore('ckpt_dir/ckpt-?')

# %%
ep_reward = []
total_avgr = []
early_stop = False
avg_rewards_list = []

env.reset_game()

for s in range(0, max_episode):
    if early_stop == True:
        break

    rewards = []
    states = []
    actions = []
    log_probs = []
    masks = []
    values = []

    display_frames = [env.getScreenRGB()]
    input_frames = [preprocess_screen(env.getScreenGrayscale())]

    for step in range(hparas['num_steps']):

        state = frames_to_state(input_frames)
        state = tf.expand_dims(state, axis=0)
        prob, value = agent.actor_critic(state)

        dist = tfp.distributions.Categorical(probs=prob[0], dtype=tf.float32)
        action = dist.sample(1)
        log_prob = dist.log_prob(action)

        reward = env.act(env.getActionSet()[int(action.numpy())])

        done = env.game_over()

        states.append(state)
        actions.append(action)
        values.append(value[0])
        log_probs.append(log_prob)
        rewards.append(tf.convert_to_tensor(reward, dtype=tf.float32))
        masks.append(tf.convert_to_tensor(1-int(done), dtype=tf.float32))

        display_frames.append(env.getScreenRGB())
        input_frames.append(preprocess_screen(env.getScreenGrayscale()))

        if done:
            env.reset_game()
            input_frames = [preprocess_screen(env.getScreenGrayscale())]

    _, next_value = agent.actor_critic(state)
    values.append(next_value[0])

    returns = compute_gae(rewards, masks, values, hparas['gamma'], hparas['lambda'])

    returns = tf.concat(returns, axis=0)
    log_probs = tf.concat(log_probs, axis=0)
    values = tf.concat(values, axis=0)
    states = tf.concat(states, axis=0)
    actions = tf.concat(actions, axis=0)
    advantage = returns - values[:-1]

    a_loss, c_loss = agent.ppo_update(hparas['ppo_epochs'], hparas['mini_batch_size'], states, actions, log_probs, returns, advantage)
    print('[Episode %d]  Actor loss: %.5f, Critic loss: %.5f' % (s, a_loss, c_loss))

    if s % test_per_n_episode == 0:
        # test agent hparas['test_epochs'] times to get the average reward
        avg_reward = np.mean([test_reward(test_env, agent) for _ in range(hparas['test_epochs'])])
        print("Test average reward is %.1f, Current best average reward is %.1f\n" % (avg_reward, best_reward))
        avg_rewards_list.append(avg_reward)

        if avg_reward > best_reward:
            best_reward = avg_reward
            # 保存为 .h5 格式
            agent.actor_critic.save('./save/Actor/model_actor_{}_{}.h5'.format(s, avg_reward))
            checkpoint.save(file_prefix = './save/checkpoints/ckpt')

    if s % force_save_per_n_episode == 0:
        # 保存为 .h5 格式
        agent.actor_critic.save('./save/Actor/model_actor_{}_{}.h5'.format(s, avg_reward))
        checkpoint.save(file_prefix = './save/checkpoints/ckpt')
        clip = make_anim(display_frames, fps=60, true_image=True).rotate(-90)
        clip.write_videofile("movie_f/{}_demo-{}.webm".format('Lab15', s), fps=60)
        display(clip.ipython_display(fps=60, autoplay=1, loop=1, maxduration=120))

    if best_reward >= early_stop_reward:
        early_stop = True
# Out:
# WARNING:py.warnings:<ipython-input-19-8475ca91eefd>:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   reward = env.act(env.getActionSet()[int(action.numpy())])
# [Episode 0]  Actor loss: 88.59031, Critic loss: 63.71158
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test average reward is -5.0, Current best average reward is -5.0
#
# Moviepy - Building video movie_f/Lab15_demo-0.webm.
# Moviepy - Writing video movie_f/Lab15_demo-0.webm
# Moviepy - Done !
# Moviepy - video ready movie_f/Lab15_demo-0.webm
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video autoplay='1' loop='1'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
# [Episode 1]  Actor loss: 54.54134, Critic loss: 37.22117
# [Episode 2]  Actor loss: 36.37086, Critic loss: 21.74653
# [Episode 3]  Actor loss: 29.47977, Critic loss: 12.18717
# [Episode 4]  Actor loss: 24.71905, Critic loss: 9.44314
# [Episode 5]  Actor loss: 3.43527, Critic loss: 5.31724
# [Episode 6]  Actor loss: 8.17182, Critic loss: 5.84671
# [Episode 7]  Actor loss: -3.89057, Critic loss: 3.43496
# [Episode 8]  Actor loss: -4.60115, Critic loss: 3.10960
# [Episode 9]  Actor loss: -8.16456, Critic loss: 2.98535
# [Episode 10]  Actor loss: -9.01003, Critic loss: 2.50381
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 11]  Actor loss: 4.32775, Critic loss: 3.18325
# [Episode 12]  Actor loss: 0.60741, Critic loss: 3.34672
# [Episode 13]  Actor loss: -2.53377, Critic loss: 2.61472
# [Episode 14]  Actor loss: -3.77342, Critic loss: 2.39350
# [Episode 15]  Actor loss: 0.75823, Critic loss: 3.32172
# [Episode 16]  Actor loss: 1.58531, Critic loss: 2.88921
# [Episode 17]  Actor loss: -3.43866, Critic loss: 2.84297
# [Episode 18]  Actor loss: -0.10282, Critic loss: 2.55833
# [Episode 19]  Actor loss: 2.00375, Critic loss: 2.93273
# [Episode 20]  Actor loss: 1.88429, Critic loss: 2.89787
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 21]  Actor loss: -6.92775, Critic loss: 1.57670
# [Episode 22]  Actor loss: -5.32276, Critic loss: 1.18630
# [Episode 23]  Actor loss: -3.31190, Critic loss: 1.78053
# [Episode 24]  Actor loss: -3.18721, Critic loss: 1.31119
# [Episode 25]  Actor loss: 0.49065, Critic loss: 1.87204
# [Episode 26]  Actor loss: -0.82391, Critic loss: 1.52578
# [Episode 27]  Actor loss: -4.13147, Critic loss: 1.07356
# [Episode 28]  Actor loss: -5.78222, Critic loss: 1.02334
# [Episode 29]  Actor loss: 0.33039, Critic loss: 0.95887
# [Episode 30]  Actor loss: -5.87210, Critic loss: 1.11460
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 31]  Actor loss: -1.63106, Critic loss: 1.57232
# [Episode 32]  Actor loss: -0.93613, Critic loss: 1.40420
# [Episode 33]  Actor loss: -2.58934, Critic loss: 0.98692
# [Episode 34]  Actor loss: -6.41686, Critic loss: 1.15865
# [Episode 35]  Actor loss: -3.19528, Critic loss: 1.18588
# [Episode 36]  Actor loss: -1.22118, Critic loss: 0.77146
# [Episode 37]  Actor loss: -0.35464, Critic loss: 1.39375
# [Episode 38]  Actor loss: -3.57243, Critic loss: 0.67981
# [Episode 39]  Actor loss: -6.30268, Critic loss: 0.50717
# [Episode 40]  Actor loss: -6.74600, Critic loss: 1.85439
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 41]  Actor loss: -4.11683, Critic loss: 0.72984
# [Episode 42]  Actor loss: -3.56803, Critic loss: 0.76104
# [Episode 43]  Actor loss: -2.63302, Critic loss: 0.78178
# [Episode 44]  Actor loss: -4.56530, Critic loss: 0.98482
# [Episode 45]  Actor loss: -4.15437, Critic loss: 0.65002
# [Episode 46]  Actor loss: -7.81307, Critic loss: 0.42072
# [Episode 47]  Actor loss: -1.19267, Critic loss: 1.36420
# [Episode 48]  Actor loss: -7.49499, Critic loss: 0.73505
# [Episode 49]  Actor loss: -7.10948, Critic loss: 0.49340
# [Episode 50]  Actor loss: -7.41448, Critic loss: 0.50092
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 51]  Actor loss: -9.21787, Critic loss: 0.90219
# [Episode 52]  Actor loss: -5.19954, Critic loss: 0.51748
# [Episode 53]  Actor loss: -6.40669, Critic loss: 0.52096
# [Episode 54]  Actor loss: -7.49801, Critic loss: 0.47142
# [Episode 55]  Actor loss: -4.60978, Critic loss: 0.83094
# [Episode 56]  Actor loss: -1.34175, Critic loss: 0.53766
# [Episode 57]  Actor loss: -2.59978, Critic loss: 0.43596
# [Episode 58]  Actor loss: -8.33354, Critic loss: 0.41476
# [Episode 59]  Actor loss: -1.42243, Critic loss: 0.61476
# [Episode 60]  Actor loss: -4.30941, Critic loss: 0.59431
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 61]  Actor loss: -7.21657, Critic loss: 0.51148
# [Episode 62]  Actor loss: -10.19309, Critic loss: 0.66900
# [Episode 63]  Actor loss: -9.07070, Critic loss: 0.53336
# [Episode 64]  Actor loss: -9.34827, Critic loss: 0.36842
# [Episode 65]  Actor loss: -7.12553, Critic loss: 0.34828
# [Episode 66]  Actor loss: -5.54751, Critic loss: 0.51192
# [Episode 67]  Actor loss: -3.40107, Critic loss: 0.65381
# [Episode 68]  Actor loss: -2.15079, Critic loss: 0.62869
# [Episode 69]  Actor loss: -9.87759, Critic loss: 1.03290
# [Episode 70]  Actor loss: -5.04231, Critic loss: 0.49432
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 71]  Actor loss: -4.51262, Critic loss: 0.57822
# [Episode 72]  Actor loss: -7.61824, Critic loss: 0.47438
# [Episode 73]  Actor loss: -7.54334, Critic loss: 2.09763
# [Episode 74]  Actor loss: -7.73440, Critic loss: 0.43465
# [Episode 75]  Actor loss: -6.33215, Critic loss: 0.33393
# [Episode 76]  Actor loss: -1.90596, Critic loss: 0.55491
# [Episode 77]  Actor loss: -3.36978, Critic loss: 0.59134
# [Episode 78]  Actor loss: -8.98394, Critic loss: 0.56632
# [Episode 79]  Actor loss: -5.79995, Critic loss: 0.47129
# [Episode 80]  Actor loss: -6.57850, Critic loss: 0.43574
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 81]  Actor loss: -6.51217, Critic loss: 1.89626
# [Episode 82]  Actor loss: -5.95462, Critic loss: 0.49713
# [Episode 83]  Actor loss: -3.46027, Critic loss: 0.46088
# [Episode 84]  Actor loss: -3.33244, Critic loss: 0.43916
# [Episode 85]  Actor loss: -1.55815, Critic loss: 0.46014
# [Episode 86]  Actor loss: -6.65053, Critic loss: 1.08898
# [Episode 87]  Actor loss: -6.85841, Critic loss: 0.58157
# [Episode 88]  Actor loss: -2.79276, Critic loss: 0.49141
# [Episode 89]  Actor loss: -1.28544, Critic loss: 0.38671
# [Episode 90]  Actor loss: -5.37731, Critic loss: 0.40624
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 91]  Actor loss: -3.82445, Critic loss: 0.63849
# [Episode 92]  Actor loss: -3.46057, Critic loss: 0.39381
# [Episode 93]  Actor loss: -4.36096, Critic loss: 0.37026
# [Episode 94]  Actor loss: -0.86747, Critic loss: 0.68390
# [Episode 95]  Actor loss: 0.72880, Critic loss: 0.64353
# [Episode 96]  Actor loss: -4.76315, Critic loss: 0.24213
# [Episode 97]  Actor loss: -5.24393, Critic loss: 0.82797
# [Episode 98]  Actor loss: -2.98041, Critic loss: 0.34411
# [Episode 99]  Actor loss: -0.86300, Critic loss: 0.33986
# [Episode 100]  Actor loss: -5.22891, Critic loss: 0.27408
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 101]  Actor loss: -4.69672, Critic loss: 0.73648
# [Episode 102]  Actor loss: -3.74344, Critic loss: 0.37365
# [Episode 103]  Actor loss: -7.68769, Critic loss: 0.42102
# [Episode 104]  Actor loss: -8.75941, Critic loss: 0.33725
# [Episode 105]  Actor loss: -4.16316, Critic loss: 0.24545
# [Episode 106]  Actor loss: -3.52712, Critic loss: 0.33739
# [Episode 107]  Actor loss: -0.94011, Critic loss: 0.40157
# [Episode 108]  Actor loss: -4.43937, Critic loss: 0.30980
# [Episode 109]  Actor loss: -8.85827, Critic loss: 0.27342
# [Episode 110]  Actor loss: -2.49133, Critic loss: 0.45432
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 111]  Actor loss: -6.02953, Critic loss: 0.33371
# [Episode 112]  Actor loss: -1.79931, Critic loss: 0.76322
# [Episode 113]  Actor loss: -1.04963, Critic loss: 0.48852
# [Episode 114]  Actor loss: -5.57429, Critic loss: 0.31417
# [Episode 115]  Actor loss: -0.99364, Critic loss: 0.47703
# [Episode 116]  Actor loss: -2.81641, Critic loss: 0.36254
# [Episode 117]  Actor loss: -3.43847, Critic loss: 0.27458
# [Episode 118]  Actor loss: -3.77339, Critic loss: 0.37061
# [Episode 119]  Actor loss: -4.59275, Critic loss: 0.23053
# [Episode 120]  Actor loss: -6.91594, Critic loss: 0.38111
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 121]  Actor loss: -3.02851, Critic loss: 0.57559
# [Episode 122]  Actor loss: -4.41993, Critic loss: 0.35734
# [Episode 123]  Actor loss: -0.27881, Critic loss: 0.36281
# [Episode 124]  Actor loss: -6.60620, Critic loss: 0.44250
# [Episode 125]  Actor loss: -4.03035, Critic loss: 0.48279
# [Episode 126]  Actor loss: -13.65942, Critic loss: 0.49182
# [Episode 127]  Actor loss: -3.92277, Critic loss: 0.48119
# [Episode 128]  Actor loss: -5.46168, Critic loss: 0.61342
# [Episode 129]  Actor loss: -5.55815, Critic loss: 0.44978
# [Episode 130]  Actor loss: -7.54379, Critic loss: 0.44036
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 131]  Actor loss: -4.36339, Critic loss: 0.50710
# [Episode 132]  Actor loss: -7.31493, Critic loss: 0.29151
# [Episode 133]  Actor loss: -6.20784, Critic loss: 0.28604
# [Episode 134]  Actor loss: -7.71074, Critic loss: 0.25552
# [Episode 135]  Actor loss: -5.17735, Critic loss: 0.29892
# [Episode 136]  Actor loss: -4.35450, Critic loss: 0.44963
# [Episode 137]  Actor loss: -5.09285, Critic loss: 0.35874
# [Episode 138]  Actor loss: -1.64010, Critic loss: 0.54471
# [Episode 139]  Actor loss: -2.36668, Critic loss: 0.50012
# [Episode 140]  Actor loss: -1.44451, Critic loss: 0.33165
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 141]  Actor loss: -7.51435, Critic loss: 0.51270
# [Episode 142]  Actor loss: -6.24537, Critic loss: 0.31511
# [Episode 143]  Actor loss: -2.51293, Critic loss: 0.22251
# [Episode 144]  Actor loss: -2.31474, Critic loss: 0.24050
# [Episode 145]  Actor loss: -9.48148, Critic loss: 1.07486
# [Episode 146]  Actor loss: -1.58290, Critic loss: 0.71132
# [Episode 147]  Actor loss: -4.52998, Critic loss: 0.58445
# [Episode 148]  Actor loss: -7.06308, Critic loss: 0.34314
# [Episode 149]  Actor loss: -9.67413, Critic loss: 0.70947
# [Episode 150]  Actor loss: 1.16524, Critic loss: 0.51842
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 151]  Actor loss: -4.18184, Critic loss: 0.28443
# [Episode 152]  Actor loss: -5.27332, Critic loss: 0.45934
# [Episode 153]  Actor loss: -8.62021, Critic loss: 0.73355
# [Episode 154]  Actor loss: -1.67934, Critic loss: 0.50320
# [Episode 155]  Actor loss: -6.00191, Critic loss: 0.41997
# [Episode 156]  Actor loss: -4.36666, Critic loss: 0.31950
# [Episode 157]  Actor loss: -4.19795, Critic loss: 1.02523
# [Episode 158]  Actor loss: -6.12761, Critic loss: 0.45826
# [Episode 159]  Actor loss: -1.19889, Critic loss: 0.62362
# [Episode 160]  Actor loss: -6.22529, Critic loss: 0.46124
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 161]  Actor loss: -3.98660, Critic loss: 0.62257
# [Episode 162]  Actor loss: -5.49250, Critic loss: 0.43033
# [Episode 163]  Actor loss: -3.89500, Critic loss: 0.32430
# [Episode 164]  Actor loss: -9.38821, Critic loss: 0.39191
# [Episode 165]  Actor loss: -4.23688, Critic loss: 0.36919
# [Episode 166]  Actor loss: -4.00772, Critic loss: 0.52437
# [Episode 167]  Actor loss: -3.45579, Critic loss: 0.31323
# [Episode 168]  Actor loss: -2.67466, Critic loss: 0.52373
# [Episode 169]  Actor loss: -3.96787, Critic loss: 0.42084
# [Episode 170]  Actor loss: -7.48506, Critic loss: 0.36664
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 171]  Actor loss: -5.98785, Critic loss: 0.56196
# [Episode 172]  Actor loss: -4.10062, Critic loss: 0.26817
# [Episode 173]  Actor loss: -7.17900, Critic loss: 0.26552
# [Episode 174]  Actor loss: -2.54232, Critic loss: 0.37690
# [Episode 175]  Actor loss: -2.39893, Critic loss: 0.26995
# [Episode 176]  Actor loss: -5.59027, Critic loss: 0.23839
# [Episode 177]  Actor loss: -4.11760, Critic loss: 0.32786
# [Episode 178]  Actor loss: -4.38815, Critic loss: 0.39310
# [Episode 179]  Actor loss: -3.36378, Critic loss: 0.33171
# [Episode 180]  Actor loss: -4.52758, Critic loss: 0.51260
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 181]  Actor loss: -5.98171, Critic loss: 0.32656
# [Episode 182]  Actor loss: -6.09643, Critic loss: 0.35537
# [Episode 183]  Actor loss: -3.01707, Critic loss: 0.38034
# [Episode 184]  Actor loss: -4.94183, Critic loss: 0.18213
# [Episode 185]  Actor loss: -11.05309, Critic loss: 0.86435
# [Episode 186]  Actor loss: -3.76126, Critic loss: 0.54662
# [Episode 187]  Actor loss: -4.87489, Critic loss: 0.33303
# [Episode 188]  Actor loss: -3.74036, Critic loss: 0.29416
# [Episode 189]  Actor loss: -7.16658, Critic loss: 0.34727
# [Episode 190]  Actor loss: 0.11975, Critic loss: 0.30893
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 191]  Actor loss: 0.38138, Critic loss: 0.51654
# [Episode 192]  Actor loss: -5.36902, Critic loss: 0.38673
# [Episode 193]  Actor loss: -7.64584, Critic loss: 0.77187
# [Episode 194]  Actor loss: -3.22050, Critic loss: 0.45146
# [Episode 195]  Actor loss: -1.01464, Critic loss: 0.45906
# [Episode 196]  Actor loss: -4.53498, Critic loss: 0.50717
# [Episode 197]  Actor loss: -3.42844, Critic loss: 0.50828
# [Episode 198]  Actor loss: -4.17528, Critic loss: 0.26573
# [Episode 199]  Actor loss: -2.72368, Critic loss: 0.45233
# [Episode 200]  Actor loss: -5.72697, Critic loss: 0.55653
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 201]  Actor loss: -8.08312, Critic loss: 0.66709
# [Episode 202]  Actor loss: -5.50914, Critic loss: 0.64697
# [Episode 203]  Actor loss: -4.22303, Critic loss: 0.52205
# [Episode 204]  Actor loss: -3.24624, Critic loss: 0.30387
# [Episode 205]  Actor loss: -4.56321, Critic loss: 0.22624
# [Episode 206]  Actor loss: -6.29174, Critic loss: 0.58559
# [Episode 207]  Actor loss: -3.96041, Critic loss: 0.28900
# [Episode 208]  Actor loss: -2.00058, Critic loss: 0.37605
# [Episode 209]  Actor loss: -4.65196, Critic loss: 0.44576
# [Episode 210]  Actor loss: -8.28934, Critic loss: 0.94233
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 211]  Actor loss: -2.69577, Critic loss: 0.84782
# [Episode 212]  Actor loss: -2.54839, Critic loss: 0.39386
# [Episode 213]  Actor loss: -3.61595, Critic loss: 0.30051
# [Episode 214]  Actor loss: -7.71315, Critic loss: 0.71658
# [Episode 215]  Actor loss: -6.87861, Critic loss: 0.73807
# [Episode 216]  Actor loss: -5.28859, Critic loss: 0.76002
# [Episode 217]  Actor loss: -8.03355, Critic loss: 0.60861
# [Episode 218]  Actor loss: -1.75324, Critic loss: 0.65975
# [Episode 219]  Actor loss: -4.10884, Critic loss: 0.58016
# [Episode 220]  Actor loss: -4.33118, Critic loss: 0.33540
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test average reward is -4.0, Current best average reward is -5.0
#
# [Episode 221]  Actor loss: -4.41581, Critic loss: 0.36187
# [Episode 222]  Actor loss: -5.83302, Critic loss: 0.36537
# [Episode 223]  Actor loss: -1.82721, Critic loss: 0.32618
# [Episode 224]  Actor loss: -7.40614, Critic loss: 0.44454
# [Episode 225]  Actor loss: -4.84624, Critic loss: 0.37156
# [Episode 226]  Actor loss: 2.01165, Critic loss: 0.51657
# [Episode 227]  Actor loss: -4.87960, Critic loss: 0.31853
# [Episode 228]  Actor loss: -4.06621, Critic loss: 0.36971
# [Episode 229]  Actor loss: -1.47981, Critic loss: 0.39603
# [Episode 230]  Actor loss: -4.85555, Critic loss: 0.26750
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 231]  Actor loss: -7.29669, Critic loss: 0.26893
# [Episode 232]  Actor loss: -7.70916, Critic loss: 0.36920
# [Episode 233]  Actor loss: -2.15687, Critic loss: 0.39655
# [Episode 234]  Actor loss: -4.65200, Critic loss: 0.35460
# [Episode 235]  Actor loss: -5.37668, Critic loss: 0.43368
# [Episode 236]  Actor loss: -6.57649, Critic loss: 0.19722
# [Episode 237]  Actor loss: -6.11428, Critic loss: 0.14736
# [Episode 238]  Actor loss: -9.95302, Critic loss: 0.66004
# [Episode 239]  Actor loss: -4.58521, Critic loss: 0.64237
# [Episode 240]  Actor loss: -1.10272, Critic loss: 0.43277
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 241]  Actor loss: -3.69962, Critic loss: 0.34804
# [Episode 242]  Actor loss: -3.76700, Critic loss: 0.79028
# [Episode 243]  Actor loss: -1.18001, Critic loss: 0.60493
# [Episode 244]  Actor loss: -4.32016, Critic loss: 0.94075
# [Episode 245]  Actor loss: -1.30891, Critic loss: 0.45270
# [Episode 246]  Actor loss: -6.23274, Critic loss: 0.42161
# [Episode 247]  Actor loss: -5.76957, Critic loss: 0.34368
# [Episode 248]  Actor loss: -4.59019, Critic loss: 0.25255
# [Episode 249]  Actor loss: -1.63480, Critic loss: 0.47898
# [Episode 250]  Actor loss: -6.79541, Critic loss: 0.46332
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 251]  Actor loss: -3.09380, Critic loss: 0.42399
# [Episode 252]  Actor loss: -6.37912, Critic loss: 0.41743
# [Episode 253]  Actor loss: -2.89541, Critic loss: 0.70471
# [Episode 254]  Actor loss: -4.84718, Critic loss: 0.35924
# [Episode 255]  Actor loss: -6.12870, Critic loss: 0.67769
# [Episode 256]  Actor loss: -6.48459, Critic loss: 0.59292
# [Episode 257]  Actor loss: -5.01375, Critic loss: 0.31564
# [Episode 258]  Actor loss: -0.67715, Critic loss: 0.41646
# [Episode 259]  Actor loss: -8.05514, Critic loss: 0.73284
# [Episode 260]  Actor loss: -5.50583, Critic loss: 0.39810
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 261]  Actor loss: 1.83809, Critic loss: 0.57179
# [Episode 262]  Actor loss: -4.08359, Critic loss: 0.57626
# [Episode 263]  Actor loss: -1.96281, Critic loss: 0.61207
# [Episode 264]  Actor loss: -1.65445, Critic loss: 0.42105
# [Episode 265]  Actor loss: -2.26875, Critic loss: 0.29906
# [Episode 266]  Actor loss: -2.81460, Critic loss: 0.34209
# [Episode 267]  Actor loss: -8.36699, Critic loss: 0.59906
# [Episode 268]  Actor loss: -5.09731, Critic loss: 0.88119
# [Episode 269]  Actor loss: -5.34484, Critic loss: 0.40497
# [Episode 270]  Actor loss: -5.23714, Critic loss: 0.33535
# Test average reward is -4.0, Current best average reward is -4.0
#
# [Episode 271]  Actor loss: -2.37885, Critic loss: 0.48155
# [Episode 272]  Actor loss: -5.83694, Critic loss: 0.63049
# [Episode 273]  Actor loss: -0.81522, Critic loss: 0.61913
# [Episode 274]  Actor loss: -0.17454, Critic loss: 0.43461
# [Episode 275]  Actor loss: -6.18262, Critic loss: 0.38560
# [Episode 276]  Actor loss: -4.21340, Critic loss: 0.38668
# [Episode 277]  Actor loss: -1.29283, Critic loss: 0.49251
# [Episode 278]  Actor loss: -3.63098, Critic loss: 0.37846
# [Episode 279]  Actor loss: -5.60310, Critic loss: 0.20848
# [Episode 280]  Actor loss: -5.59541, Critic loss: 0.23152
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 281]  Actor loss: -3.35915, Critic loss: 0.45093
# [Episode 282]  Actor loss: -7.91597, Critic loss: 0.62622
# [Episode 283]  Actor loss: -10.04806, Critic loss: 0.31162
# [Episode 284]  Actor loss: -5.95138, Critic loss: 0.26614
# [Episode 285]  Actor loss: -3.36263, Critic loss: 0.39229
# [Episode 286]  Actor loss: -5.06462, Critic loss: 0.40629
# [Episode 287]  Actor loss: -5.22636, Critic loss: 0.37108
# [Episode 288]  Actor loss: -5.11533, Critic loss: 0.27084
# [Episode 289]  Actor loss: -2.49610, Critic loss: 0.31804
# [Episode 290]  Actor loss: -4.83120, Critic loss: 0.31219
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 291]  Actor loss: -6.08377, Critic loss: 0.41986
# [Episode 292]  Actor loss: -8.22001, Critic loss: 1.11970
# [Episode 293]  Actor loss: -0.59947, Critic loss: 0.51603
# [Episode 294]  Actor loss: -5.63141, Critic loss: 0.21426
# [Episode 295]  Actor loss: -2.31256, Critic loss: 0.47530
# [Episode 296]  Actor loss: -11.01695, Critic loss: 0.76995
# [Episode 297]  Actor loss: -4.51745, Critic loss: 0.51139
# [Episode 298]  Actor loss: -7.22120, Critic loss: 0.79444
# [Episode 299]  Actor loss: -1.40223, Critic loss: 0.36557
# [Episode 300]  Actor loss: -5.64670, Critic loss: 0.44082
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 301]  Actor loss: -3.92458, Critic loss: 0.32098
# [Episode 302]  Actor loss: -1.23141, Critic loss: 0.35529
# [Episode 303]  Actor loss: -3.98983, Critic loss: 0.25304
# [Episode 304]  Actor loss: -6.49093, Critic loss: 0.39269
# [Episode 305]  Actor loss: -2.92700, Critic loss: 0.27981
# [Episode 306]  Actor loss: -6.27856, Critic loss: 0.35429
# [Episode 307]  Actor loss: -4.85122, Critic loss: 0.54098
# [Episode 308]  Actor loss: -4.20649, Critic loss: 0.34828
# [Episode 309]  Actor loss: -1.65511, Critic loss: 0.43066
# [Episode 310]  Actor loss: -0.94238, Critic loss: 0.26635
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 311]  Actor loss: -4.18406, Critic loss: 0.46458
# [Episode 312]  Actor loss: -3.11848, Critic loss: 0.61404
# [Episode 313]  Actor loss: -3.80023, Critic loss: 0.40683
# [Episode 314]  Actor loss: -7.47130, Critic loss: 0.34147
# [Episode 315]  Actor loss: -7.07782, Critic loss: 0.52172
# [Episode 316]  Actor loss: -1.44367, Critic loss: 0.54529
# [Episode 317]  Actor loss: -0.96045, Critic loss: 0.35716
# [Episode 318]  Actor loss: -6.81036, Critic loss: 0.52941
# [Episode 319]  Actor loss: -9.73763, Critic loss: 0.25248
# [Episode 320]  Actor loss: -3.63513, Critic loss: 0.69777
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 321]  Actor loss: -5.56725, Critic loss: 0.40321
# [Episode 322]  Actor loss: -3.92612, Critic loss: 0.34301
# [Episode 323]  Actor loss: -2.39239, Critic loss: 0.26889
# [Episode 324]  Actor loss: -0.59438, Critic loss: 0.28292
# [Episode 325]  Actor loss: -5.15246, Critic loss: 0.33469
# [Episode 326]  Actor loss: -4.79056, Critic loss: 0.36643
# [Episode 327]  Actor loss: -8.48468, Critic loss: 0.41177
# [Episode 328]  Actor loss: -4.07202, Critic loss: 0.42635
# [Episode 329]  Actor loss: -1.09112, Critic loss: 0.32006
# [Episode 330]  Actor loss: -4.62020, Critic loss: 0.26079
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 331]  Actor loss: -4.22381, Critic loss: 0.34701
# [Episode 332]  Actor loss: -7.50078, Critic loss: 0.24064
# [Episode 333]  Actor loss: -2.89526, Critic loss: 0.31447
# [Episode 334]  Actor loss: -5.39009, Critic loss: 0.36295
# [Episode 335]  Actor loss: -3.73725, Critic loss: 0.19819
# [Episode 336]  Actor loss: -6.82452, Critic loss: 0.20255
# [Episode 337]  Actor loss: -3.03637, Critic loss: 0.38057
# [Episode 338]  Actor loss: -3.92344, Critic loss: 0.26389
# [Episode 339]  Actor loss: -1.45482, Critic loss: 0.51801
# [Episode 340]  Actor loss: -5.40962, Critic loss: 1.27928
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 341]  Actor loss: -1.07080, Critic loss: 0.36313
# [Episode 342]  Actor loss: -6.08943, Critic loss: 0.36130
# [Episode 343]  Actor loss: -6.43834, Critic loss: 0.64300
# [Episode 344]  Actor loss: -3.67762, Critic loss: 0.32540
# [Episode 345]  Actor loss: -2.26080, Critic loss: 0.48643
# [Episode 346]  Actor loss: -3.57700, Critic loss: 0.26628
# [Episode 347]  Actor loss: -4.37504, Critic loss: 0.65739
# [Episode 348]  Actor loss: -5.85999, Critic loss: 0.60310
# [Episode 349]  Actor loss: -8.39319, Critic loss: 0.60038
# [Episode 350]  Actor loss: -8.68629, Critic loss: 0.88991
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 351]  Actor loss: -3.90863, Critic loss: 0.70959
# [Episode 352]  Actor loss: -4.89679, Critic loss: 0.33596
# [Episode 353]  Actor loss: -5.05683, Critic loss: 0.69952
# [Episode 354]  Actor loss: -4.23482, Critic loss: 0.62337
# [Episode 355]  Actor loss: -3.23715, Critic loss: 0.52812
# [Episode 356]  Actor loss: -2.41250, Critic loss: 0.46297
# [Episode 357]  Actor loss: -7.30279, Critic loss: 0.29000
# [Episode 358]  Actor loss: -7.59369, Critic loss: 0.29056
# [Episode 359]  Actor loss: -6.34362, Critic loss: 0.32343
# [Episode 360]  Actor loss: -6.75197, Critic loss: 0.44979
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 361]  Actor loss: -5.04900, Critic loss: 0.40848
# [Episode 362]  Actor loss: -8.67173, Critic loss: 0.68950
# [Episode 363]  Actor loss: -2.44729, Critic loss: 0.49740
# [Episode 364]  Actor loss: -6.66937, Critic loss: 0.29934
# [Episode 365]  Actor loss: -3.82966, Critic loss: 0.38022
# [Episode 366]  Actor loss: -4.75403, Critic loss: 0.42247
# [Episode 367]  Actor loss: -4.40409, Critic loss: 0.28381
# [Episode 368]  Actor loss: -6.01042, Critic loss: 0.36398
# [Episode 369]  Actor loss: -8.75278, Critic loss: 0.59567
# [Episode 370]  Actor loss: 0.42867, Critic loss: 0.40268
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 371]  Actor loss: -5.23108, Critic loss: 0.51203
# [Episode 372]  Actor loss: -4.02286, Critic loss: 0.34599
# [Episode 373]  Actor loss: -0.39083, Critic loss: 0.37287
# [Episode 374]  Actor loss: -8.08735, Critic loss: 0.93250
# [Episode 375]  Actor loss: -0.94686, Critic loss: 0.51216
# [Episode 376]  Actor loss: -5.10251, Critic loss: 0.23378
# [Episode 377]  Actor loss: -4.33500, Critic loss: 0.34500
# [Episode 378]  Actor loss: -4.53149, Critic loss: 0.40650
# [Episode 379]  Actor loss: -6.05818, Critic loss: 0.25839
# [Episode 380]  Actor loss: -5.79782, Critic loss: 0.19197
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 381]  Actor loss: -2.36974, Critic loss: 0.40548
# [Episode 382]  Actor loss: -4.56170, Critic loss: 0.31276
# [Episode 383]  Actor loss: -1.79268, Critic loss: 0.33616
# [Episode 384]  Actor loss: -5.26225, Critic loss: 0.75768
# [Episode 385]  Actor loss: -5.36321, Critic loss: 0.65183
# [Episode 386]  Actor loss: -1.32671, Critic loss: 0.37658
# [Episode 387]  Actor loss: -6.75731, Critic loss: 0.32244
# [Episode 388]  Actor loss: -4.66662, Critic loss: 0.15877
# [Episode 389]  Actor loss: -6.08518, Critic loss: 0.19811
# [Episode 390]  Actor loss: -10.67806, Critic loss: 1.26420
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 391]  Actor loss: -2.11327, Critic loss: 0.47008
# [Episode 392]  Actor loss: -0.92191, Critic loss: 0.33165
# [Episode 393]  Actor loss: -7.52069, Critic loss: 0.35231
# [Episode 394]  Actor loss: -6.08185, Critic loss: 0.29384
# [Episode 395]  Actor loss: -6.16256, Critic loss: 0.28418
# [Episode 396]  Actor loss: -7.52530, Critic loss: 0.58977
# [Episode 397]  Actor loss: -2.58124, Critic loss: 0.58000
# [Episode 398]  Actor loss: -1.82614, Critic loss: 0.50194
# [Episode 399]  Actor loss: -0.93221, Critic loss: 0.35935
# [Episode 400]  Actor loss: -2.16612, Critic loss: 0.28460
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 401]  Actor loss: -7.77086, Critic loss: 0.84483
# [Episode 402]  Actor loss: -2.04167, Critic loss: 0.48552
# [Episode 403]  Actor loss: -3.14488, Critic loss: 0.27808
# [Episode 404]  Actor loss: -10.34924, Critic loss: 1.15770
# [Episode 405]  Actor loss: -7.12619, Critic loss: 0.56213
# [Episode 406]  Actor loss: -5.70985, Critic loss: 0.82529
# [Episode 407]  Actor loss: 0.72272, Critic loss: 0.45581
# [Episode 408]  Actor loss: -1.94617, Critic loss: 0.54024
# [Episode 409]  Actor loss: -6.90473, Critic loss: 0.41022
# [Episode 410]  Actor loss: -4.76927, Critic loss: 0.77252
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 411]  Actor loss: -0.83882, Critic loss: 0.61518
# [Episode 412]  Actor loss: -2.30320, Critic loss: 0.34401
# [Episode 413]  Actor loss: -8.75423, Critic loss: 1.02111
# [Episode 414]  Actor loss: -13.80466, Critic loss: 2.60646
# [Episode 415]  Actor loss: 0.39701, Critic loss: 0.80381
# [Episode 416]  Actor loss: -8.78537, Critic loss: 1.10488
# [Episode 417]  Actor loss: -0.64933, Critic loss: 0.67257
# [Episode 418]  Actor loss: -6.28140, Critic loss: 0.85884
# [Episode 419]  Actor loss: -7.14086, Critic loss: 0.37028
# [Episode 420]  Actor loss: -5.99236, Critic loss: 0.40349
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 421]  Actor loss: -2.87774, Critic loss: 0.33303
# [Episode 422]  Actor loss: -4.14826, Critic loss: 0.49224
# [Episode 423]  Actor loss: -12.38824, Critic loss: 0.69930
# [Episode 424]  Actor loss: -10.76227, Critic loss: 0.87919
# [Episode 425]  Actor loss: -7.97909, Critic loss: 0.98291
# [Episode 426]  Actor loss: -2.12696, Critic loss: 0.56691
# [Episode 427]  Actor loss: -4.09923, Critic loss: 0.36919
# [Episode 428]  Actor loss: -9.77425, Critic loss: 0.68380
# [Episode 429]  Actor loss: -5.62845, Critic loss: 0.63135
# [Episode 430]  Actor loss: -3.76193, Critic loss: 0.53186
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 431]  Actor loss: -2.31993, Critic loss: 0.28636
# [Episode 432]  Actor loss: -9.08634, Critic loss: 0.69844
# [Episode 433]  Actor loss: -1.59978, Critic loss: 0.38996
# [Episode 434]  Actor loss: -4.29524, Critic loss: 0.20346
# [Episode 435]  Actor loss: -4.93124, Critic loss: 0.27196
# [Episode 436]  Actor loss: -7.51522, Critic loss: 0.57001
# [Episode 437]  Actor loss: -9.17583, Critic loss: 0.31200
# [Episode 438]  Actor loss: -4.52451, Critic loss: 0.27617
# [Episode 439]  Actor loss: -7.87043, Critic loss: 0.84310
# [Episode 440]  Actor loss: -1.74566, Critic loss: 0.38268
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 441]  Actor loss: -7.42176, Critic loss: 0.66537
# [Episode 442]  Actor loss: -4.61373, Critic loss: 0.41757
# [Episode 443]  Actor loss: -0.79800, Critic loss: 0.60056
# [Episode 444]  Actor loss: 0.46371, Critic loss: 0.38155
# [Episode 445]  Actor loss: -4.32034, Critic loss: 0.60220
# [Episode 446]  Actor loss: -3.47542, Critic loss: 0.34451
# [Episode 447]  Actor loss: -5.08552, Critic loss: 0.50733
# [Episode 448]  Actor loss: -3.29225, Critic loss: 0.37321
# [Episode 449]  Actor loss: -6.58805, Critic loss: 0.48116
# [Episode 450]  Actor loss: -3.11807, Critic loss: 0.42710
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 451]  Actor loss: -3.06460, Critic loss: 0.38355
# [Episode 452]  Actor loss: -6.51567, Critic loss: 0.69807
# [Episode 453]  Actor loss: -2.38681, Critic loss: 0.31987
# [Episode 454]  Actor loss: -5.56544, Critic loss: 1.07983
# [Episode 455]  Actor loss: -4.27988, Critic loss: 0.52292
# [Episode 456]  Actor loss: -2.41700, Critic loss: 0.65125
# [Episode 457]  Actor loss: -11.74259, Critic loss: 1.18333
# [Episode 458]  Actor loss: -2.24291, Critic loss: 0.39675
# [Episode 459]  Actor loss: 0.48618, Critic loss: 0.36393
# [Episode 460]  Actor loss: -0.96472, Critic loss: 0.48069
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 461]  Actor loss: -1.53821, Critic loss: 0.27209
# [Episode 462]  Actor loss: -2.63911, Critic loss: 0.31224
# [Episode 463]  Actor loss: -7.18556, Critic loss: 0.61802
# [Episode 464]  Actor loss: -4.70726, Critic loss: 0.32671
# [Episode 465]  Actor loss: -3.53822, Critic loss: 0.22855
# [Episode 466]  Actor loss: -7.13380, Critic loss: 0.32164
# [Episode 467]  Actor loss: -2.74535, Critic loss: 0.37951
# [Episode 468]  Actor loss: -5.63564, Critic loss: 0.53555
# [Episode 469]  Actor loss: -5.89448, Critic loss: 0.30288
# [Episode 470]  Actor loss: -9.27362, Critic loss: 1.13979
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 471]  Actor loss: -4.01063, Critic loss: 0.42564
# [Episode 472]  Actor loss: -9.96779, Critic loss: 1.02570
# [Episode 473]  Actor loss: -3.88422, Critic loss: 1.73245
# [Episode 474]  Actor loss: -7.18656, Critic loss: 1.32929
# [Episode 475]  Actor loss: -4.52714, Critic loss: 1.35349
# [Episode 476]  Actor loss: -3.12972, Critic loss: 1.14958
# [Episode 477]  Actor loss: -2.14589, Critic loss: 0.47981
# [Episode 478]  Actor loss: -1.12668, Critic loss: 0.48744
# [Episode 479]  Actor loss: -4.47340, Critic loss: 0.54557
# [Episode 480]  Actor loss: -0.85997, Critic loss: 0.43134
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 481]  Actor loss: -3.55157, Critic loss: 0.27660
# [Episode 482]  Actor loss: -2.25471, Critic loss: 0.29479
# [Episode 483]  Actor loss: -2.50053, Critic loss: 0.34818
# [Episode 484]  Actor loss: -4.06068, Critic loss: 0.27234
# [Episode 485]  Actor loss: -5.22338, Critic loss: 0.39210
# [Episode 486]  Actor loss: -3.62592, Critic loss: 0.28792
# [Episode 487]  Actor loss: -7.43710, Critic loss: 0.61786
# [Episode 488]  Actor loss: -15.72223, Critic loss: 1.12252
# [Episode 489]  Actor loss: -6.80222, Critic loss: 0.58074
# [Episode 490]  Actor loss: -4.39351, Critic loss: 0.82283
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 491]  Actor loss: 0.94831, Critic loss: 0.41639
# [Episode 492]  Actor loss: -6.78780, Critic loss: 0.80805
# [Episode 493]  Actor loss: -5.34531, Critic loss: 0.30669
# [Episode 494]  Actor loss: -8.45592, Critic loss: 0.97997
# [Episode 495]  Actor loss: -6.47605, Critic loss: 0.34569
# [Episode 496]  Actor loss: -5.06923, Critic loss: 0.27555
# [Episode 497]  Actor loss: -11.83711, Critic loss: 0.84490
# [Episode 498]  Actor loss: -1.91468, Critic loss: 0.59458
# [Episode 499]  Actor loss: -4.39438, Critic loss: 0.71167
# [Episode 500]  Actor loss: -3.50736, Critic loss: 0.84336
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 501]  Actor loss: 0.99329, Critic loss: 0.47483
# [Episode 502]  Actor loss: -3.67507, Critic loss: 0.30575
# [Episode 503]  Actor loss: -8.78382, Critic loss: 1.31131
# [Episode 504]  Actor loss: -4.32938, Critic loss: 0.24811
# [Episode 505]  Actor loss: -10.57023, Critic loss: 0.92565
# [Episode 506]  Actor loss: -1.21397, Critic loss: 0.67350
# [Episode 507]  Actor loss: -7.86268, Critic loss: 0.54206
# [Episode 508]  Actor loss: -7.67264, Critic loss: 0.26949
# [Episode 509]  Actor loss: -4.63962, Critic loss: 0.90448
# [Episode 510]  Actor loss: -8.71843, Critic loss: 0.82785
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 511]  Actor loss: -3.46901, Critic loss: 0.49124
# [Episode 512]  Actor loss: -6.84670, Critic loss: 0.94753
# [Episode 513]  Actor loss: -8.85650, Critic loss: 0.89028
# [Episode 514]  Actor loss: -10.77918, Critic loss: 1.80401
# [Episode 515]  Actor loss: 3.06829, Critic loss: 0.81492
# [Episode 516]  Actor loss: -10.90187, Critic loss: 0.99660
# [Episode 517]  Actor loss: -5.55243, Critic loss: 0.79488
# [Episode 518]  Actor loss: -1.00697, Critic loss: 0.72287
# [Episode 519]  Actor loss: -3.70260, Critic loss: 0.92361
# [Episode 520]  Actor loss: 0.62506, Critic loss: 0.53553
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 521]  Actor loss: -6.85121, Critic loss: 1.31884
# [Episode 522]  Actor loss: -13.30997, Critic loss: 0.98104
# [Episode 523]  Actor loss: -7.27650, Critic loss: 0.64771
# [Episode 524]  Actor loss: -4.68342, Critic loss: 1.18123
# [Episode 525]  Actor loss: -8.05748, Critic loss: 1.03578
# [Episode 526]  Actor loss: -8.66854, Critic loss: 1.32348
# [Episode 527]  Actor loss: -4.08423, Critic loss: 0.25890
# [Episode 528]  Actor loss: -2.76943, Critic loss: 0.64386
# [Episode 529]  Actor loss: -0.84724, Critic loss: 0.28134
# [Episode 530]  Actor loss: 0.85193, Critic loss: 0.46471
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 531]  Actor loss: -8.38579, Critic loss: 0.89358
# [Episode 532]  Actor loss: -6.27065, Critic loss: 0.74581
# [Episode 533]  Actor loss: -7.65301, Critic loss: 0.35771
# [Episode 534]  Actor loss: -4.10287, Critic loss: 0.83488
# [Episode 535]  Actor loss: -1.99422, Critic loss: 0.35530
# [Episode 536]  Actor loss: -0.73240, Critic loss: 0.39823
# [Episode 537]  Actor loss: -0.63387, Critic loss: 0.39127
# [Episode 538]  Actor loss: -3.67013, Critic loss: 0.19541
# [Episode 539]  Actor loss: -4.51849, Critic loss: 0.39285
# [Episode 540]  Actor loss: -4.45560, Critic loss: 0.65325
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 541]  Actor loss: -15.95202, Critic loss: 1.39655
# [Episode 542]  Actor loss: -6.04594, Critic loss: 0.65328
# [Episode 543]  Actor loss: -5.42014, Critic loss: 0.99027
# [Episode 544]  Actor loss: -1.79328, Critic loss: 0.37832
# [Episode 545]  Actor loss: -4.88354, Critic loss: 0.50044
# [Episode 546]  Actor loss: -4.35379, Critic loss: 0.28013
# [Episode 547]  Actor loss: -2.92547, Critic loss: 0.28573
# [Episode 548]  Actor loss: -2.57572, Critic loss: 0.43363
# [Episode 549]  Actor loss: -5.30904, Critic loss: 0.31045
# [Episode 550]  Actor loss: -4.72695, Critic loss: 0.93525
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 551]  Actor loss: -11.23552, Critic loss: 0.76833
# [Episode 552]  Actor loss: -17.85618, Critic loss: 1.28910
# [Episode 553]  Actor loss: 2.09362, Critic loss: 1.03375
# [Episode 554]  Actor loss: -3.15814, Critic loss: 1.04984
# [Episode 555]  Actor loss: -2.80825, Critic loss: 0.80205
# [Episode 556]  Actor loss: -0.11432, Critic loss: 1.38955
# [Episode 557]  Actor loss: 1.96458, Critic loss: 0.44647
# [Episode 558]  Actor loss: -3.20662, Critic loss: 0.40889
# [Episode 559]  Actor loss: -3.12111, Critic loss: 0.31939
# [Episode 560]  Actor loss: -2.61748, Critic loss: 0.30331
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 561]  Actor loss: -0.24242, Critic loss: 0.45540
# [Episode 562]  Actor loss: -2.89286, Critic loss: 0.51240
# [Episode 563]  Actor loss: -10.35405, Critic loss: 0.71306
# [Episode 564]  Actor loss: -5.90814, Critic loss: 0.21638
# [Episode 565]  Actor loss: -8.86769, Critic loss: 0.57142
# [Episode 566]  Actor loss: -5.29527, Critic loss: 0.27968
# [Episode 567]  Actor loss: -2.32803, Critic loss: 0.35263
# [Episode 568]  Actor loss: -9.59643, Critic loss: 0.68157
# [Episode 569]  Actor loss: -13.17878, Critic loss: 1.18925
# [Episode 570]  Actor loss: 0.12717, Critic loss: 0.49978
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 571]  Actor loss: -1.80780, Critic loss: 0.38393
# [Episode 572]  Actor loss: -7.66229, Critic loss: 0.79660
# [Episode 573]  Actor loss: -3.94486, Critic loss: 0.34410
# [Episode 574]  Actor loss: -5.21301, Critic loss: 0.52620
# [Episode 575]  Actor loss: -7.82589, Critic loss: 0.67177
# [Episode 576]  Actor loss: -1.24408, Critic loss: 0.37952
# [Episode 577]  Actor loss: -4.43863, Critic loss: 0.38962
# [Episode 578]  Actor loss: -9.36499, Critic loss: 0.98899
# [Episode 579]  Actor loss: -3.79666, Critic loss: 0.46936
# [Episode 580]  Actor loss: -9.82691, Critic loss: 0.52838
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 581]  Actor loss: -3.06538, Critic loss: 0.50204
# [Episode 582]  Actor loss: -10.04856, Critic loss: 0.59941
# [Episode 583]  Actor loss: -9.76569, Critic loss: 0.53987
# [Episode 584]  Actor loss: -3.42305, Critic loss: 0.45779
# [Episode 585]  Actor loss: -8.42315, Critic loss: 0.72452
# [Episode 586]  Actor loss: -0.28047, Critic loss: 0.40489
# [Episode 587]  Actor loss: 1.01912, Critic loss: 0.33283
# [Episode 588]  Actor loss: -1.89410, Critic loss: 0.20817
# [Episode 589]  Actor loss: -3.82843, Critic loss: 0.36892
# [Episode 590]  Actor loss: -4.97163, Critic loss: 0.30733
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 591]  Actor loss: -6.54211, Critic loss: 0.11552
# [Episode 592]  Actor loss: -7.50349, Critic loss: 0.36884
# [Episode 593]  Actor loss: -6.19164, Critic loss: 0.55043
# [Episode 594]  Actor loss: -3.09190, Critic loss: 0.60778
# [Episode 595]  Actor loss: -2.45758, Critic loss: 0.35143
# [Episode 596]  Actor loss: -7.11455, Critic loss: 0.58957
# [Episode 597]  Actor loss: 0.28315, Critic loss: 0.35474
# [Episode 598]  Actor loss: -3.62911, Critic loss: 0.36353
# [Episode 599]  Actor loss: -6.52823, Critic loss: 0.74089
# [Episode 600]  Actor loss: -4.97862, Critic loss: 0.24178
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 601]  Actor loss: -8.62376, Critic loss: 0.65754
# [Episode 602]  Actor loss: -8.02246, Critic loss: 0.49518
# [Episode 603]  Actor loss: -6.03517, Critic loss: 0.45559
# [Episode 604]  Actor loss: -4.82963, Critic loss: 0.24499
# [Episode 605]  Actor loss: -10.50048, Critic loss: 0.95081
# [Episode 606]  Actor loss: 0.90531, Critic loss: 0.52375
# [Episode 607]  Actor loss: -5.05823, Critic loss: 1.15593
# [Episode 608]  Actor loss: -4.77624, Critic loss: 0.66274
# [Episode 609]  Actor loss: -5.12824, Critic loss: 0.40706
# [Episode 610]  Actor loss: -2.96314, Critic loss: 0.89048
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 611]  Actor loss: -6.91754, Critic loss: 0.61340
# [Episode 612]  Actor loss: -8.13533, Critic loss: 0.22035
# [Episode 613]  Actor loss: -6.94993, Critic loss: 0.66586
# [Episode 614]  Actor loss: -6.35650, Critic loss: 0.93608
# [Episode 615]  Actor loss: -4.87790, Critic loss: 0.70575
# [Episode 616]  Actor loss: -4.65067, Critic loss: 0.69482
# [Episode 617]  Actor loss: -9.32170, Critic loss: 0.91272
# [Episode 618]  Actor loss: -7.54416, Critic loss: 1.10381
# [Episode 619]  Actor loss: -6.37668, Critic loss: 0.94952
# [Episode 620]  Actor loss: -4.17087, Critic loss: 0.65997
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 621]  Actor loss: -1.16462, Critic loss: 0.46184
# [Episode 622]  Actor loss: -4.28350, Critic loss: 0.61241
# [Episode 623]  Actor loss: -8.53415, Critic loss: 0.86747
# [Episode 624]  Actor loss: -6.13767, Critic loss: 0.44006
# [Episode 625]  Actor loss: 0.62109, Critic loss: 0.60964
# [Episode 626]  Actor loss: -6.02467, Critic loss: 0.47610
# [Episode 627]  Actor loss: -4.89491, Critic loss: 0.67979
# [Episode 628]  Actor loss: -2.87993, Critic loss: 0.61323
# [Episode 629]  Actor loss: -1.17619, Critic loss: 0.68465
# [Episode 630]  Actor loss: -2.56085, Critic loss: 0.52437
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 631]  Actor loss: -3.25008, Critic loss: 0.47762
# [Episode 632]  Actor loss: -7.73081, Critic loss: 0.25825
# [Episode 633]  Actor loss: -12.01272, Critic loss: 1.25102
# [Episode 634]  Actor loss: -10.06731, Critic loss: 1.04528
# [Episode 635]  Actor loss: -8.61792, Critic loss: 0.95785
# [Episode 636]  Actor loss: -2.45265, Critic loss: 2.06415
# [Episode 637]  Actor loss: -2.87235, Critic loss: 0.87334
# [Episode 638]  Actor loss: 0.40522, Critic loss: 0.46489
# [Episode 639]  Actor loss: -8.28166, Critic loss: 0.86242
# [Episode 640]  Actor loss: -8.94950, Critic loss: 1.67023
# Test average reward is -4.0, Current best average reward is -4.0
#
# [Episode 641]  Actor loss: -3.66200, Critic loss: 0.70518
# [Episode 642]  Actor loss: -5.96871, Critic loss: 0.81450
# [Episode 643]  Actor loss: -3.94630, Critic loss: 1.45817
# [Episode 644]  Actor loss: -3.43225, Critic loss: 1.92553
# [Episode 645]  Actor loss: -1.18345, Critic loss: 0.31665
# [Episode 646]  Actor loss: -7.61362, Critic loss: 1.12350
# [Episode 647]  Actor loss: -1.12979, Critic loss: 0.41557
# [Episode 648]  Actor loss: -2.22556, Critic loss: 0.48048
# [Episode 649]  Actor loss: -4.93276, Critic loss: 0.72379
# [Episode 650]  Actor loss: 0.11938, Critic loss: 0.71579
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 651]  Actor loss: -6.73129, Critic loss: 0.63981
# [Episode 652]  Actor loss: -6.82170, Critic loss: 0.56772
# [Episode 653]  Actor loss: -0.72644, Critic loss: 0.63315
# [Episode 654]  Actor loss: -4.31549, Critic loss: 0.33898
# [Episode 655]  Actor loss: -4.02928, Critic loss: 0.92592
# [Episode 656]  Actor loss: -10.49570, Critic loss: 0.81029
# [Episode 657]  Actor loss: -9.02864, Critic loss: 1.39365
# [Episode 658]  Actor loss: -3.75876, Critic loss: 0.72374
# [Episode 659]  Actor loss: -4.77667, Critic loss: 0.52452
# [Episode 660]  Actor loss: -12.27005, Critic loss: 0.94641
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 661]  Actor loss: -5.51323, Critic loss: 1.63567
# [Episode 662]  Actor loss: -10.11759, Critic loss: 1.18977
# [Episode 663]  Actor loss: -1.58334, Critic loss: 1.73047
# [Episode 664]  Actor loss: -7.32251, Critic loss: 1.18362
# [Episode 665]  Actor loss: -4.41655, Critic loss: 1.67544
# [Episode 666]  Actor loss: -2.67296, Critic loss: 1.04448
# [Episode 667]  Actor loss: 4.68130, Critic loss: 1.28462
# [Episode 668]  Actor loss: -5.80902, Critic loss: 0.86815
# [Episode 669]  Actor loss: 1.55324, Critic loss: 0.88637
# [Episode 670]  Actor loss: -1.46561, Critic loss: 0.63448
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 671]  Actor loss: -3.37961, Critic loss: 0.50361
# [Episode 672]  Actor loss: -5.80543, Critic loss: 0.99233
# [Episode 673]  Actor loss: -2.98332, Critic loss: 0.28315
# [Episode 674]  Actor loss: -4.09842, Critic loss: 0.38735
# [Episode 675]  Actor loss: -11.08517, Critic loss: 1.05704
# [Episode 676]  Actor loss: -3.95186, Critic loss: 0.75056
# [Episode 677]  Actor loss: 0.45927, Critic loss: 0.41520
# [Episode 678]  Actor loss: -5.01339, Critic loss: 0.54887
# [Episode 679]  Actor loss: -3.62951, Critic loss: 0.31148
# [Episode 680]  Actor loss: -6.29985, Critic loss: 0.67647
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 681]  Actor loss: -0.56303, Critic loss: 0.36801
# [Episode 682]  Actor loss: 0.53228, Critic loss: 0.55758
# [Episode 683]  Actor loss: -5.88666, Critic loss: 0.33283
# [Episode 684]  Actor loss: -1.03676, Critic loss: 0.23306
# [Episode 685]  Actor loss: -8.94345, Critic loss: 0.59552
# [Episode 686]  Actor loss: -6.80982, Critic loss: 0.82433
# [Episode 687]  Actor loss: -5.78043, Critic loss: 0.25415
# [Episode 688]  Actor loss: -6.77811, Critic loss: 0.25718
# [Episode 689]  Actor loss: -5.52486, Critic loss: 0.47008
# [Episode 690]  Actor loss: 0.21011, Critic loss: 0.33997
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 691]  Actor loss: -3.93962, Critic loss: 0.69342
# [Episode 692]  Actor loss: -8.43376, Critic loss: 0.44938
# [Episode 693]  Actor loss: -8.38946, Critic loss: 0.49141
# [Episode 694]  Actor loss: -8.87593, Critic loss: 1.07920
# [Episode 695]  Actor loss: -2.94306, Critic loss: 0.26081
# [Episode 696]  Actor loss: -5.83666, Critic loss: 0.61400
# [Episode 697]  Actor loss: 2.17405, Critic loss: 0.84534
# [Episode 698]  Actor loss: -3.50928, Critic loss: 0.27425
# [Episode 699]  Actor loss: -4.89482, Critic loss: 0.29325
# [Episode 700]  Actor loss: -2.55733, Critic loss: 0.34632
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 701]  Actor loss: -4.90666, Critic loss: 0.22422
# [Episode 702]  Actor loss: -15.30206, Critic loss: 0.90502
# [Episode 703]  Actor loss: -0.60190, Critic loss: 0.24536
# [Episode 704]  Actor loss: -3.62580, Critic loss: 0.46592
# [Episode 705]  Actor loss: -0.95767, Critic loss: 0.28303
# [Episode 706]  Actor loss: -3.15148, Critic loss: 0.18537
# [Episode 707]  Actor loss: -5.27541, Critic loss: 0.36421
# [Episode 708]  Actor loss: -10.86402, Critic loss: 0.41531
# [Episode 709]  Actor loss: -11.18572, Critic loss: 0.67265
# [Episode 710]  Actor loss: -1.60150, Critic loss: 0.76397
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 711]  Actor loss: -1.12673, Critic loss: 0.47567
# [Episode 712]  Actor loss: -11.77859, Critic loss: 0.76021
# [Episode 713]  Actor loss: -10.09881, Critic loss: 1.58049
# [Episode 714]  Actor loss: -5.11291, Critic loss: 0.84618
# [Episode 715]  Actor loss: -5.98566, Critic loss: 0.35177
# [Episode 716]  Actor loss: -9.12355, Critic loss: 1.29598
# [Episode 717]  Actor loss: -2.04718, Critic loss: 0.94385
# [Episode 718]  Actor loss: -12.43270, Critic loss: 1.41140
# [Episode 719]  Actor loss: -0.36065, Critic loss: 0.57478
# [Episode 720]  Actor loss: -8.46199, Critic loss: 1.17266
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 721]  Actor loss: -4.73204, Critic loss: 0.57513
# ...
# [Episode 3344]  Actor loss: -3.45726, Critic loss: 5.69574
# [Episode 3345]  Actor loss: 28.07961, Critic loss: 6.74833
# [Episode 3346]  Actor loss: 5.62166, Critic loss: 6.33633
# [Episode 3347]  Actor loss: 16.25639, Critic loss: 3.16539
# [Episode 3348]  Actor loss: 9.94936, Critic loss: 2.21661
# [Episode 3349]  Actor loss: 1.53589, Critic loss: 1.09855
# [Episode 3350]  Actor loss: -4.28201, Critic loss: 3.29860
# Test average reward is -5.0, Current best average reward is 9.0
#
# [Episode 3351]  Actor loss: -1.15850, Critic loss: 2.05631
# [Episode 3352]  Actor loss: -2.55627, Critic loss: 0.82759
# [Episode 3353]  Actor loss: -1.04077, Critic loss: 0.65567
# [Episode 3354]  Actor loss: -5.85251, Critic loss: 0.83022
# [Episode 3355]  Actor loss: -12.92526, Critic loss: 1.84556
# [Episode 3356]  Actor loss: -8.91766, Critic loss: 2.29254
# [Episode 3357]  Actor loss: -9.62963, Critic loss: 2.92418
# [Episode 3358]  Actor loss: -37.72400, Critic loss: 3.78216
# [Episode 3359]  Actor loss: -19.62641, Critic loss: 7.38875
# [Episode 3360]  Actor loss: -17.81581, Critic loss: 4.23265
# Test average reward is -4.0, Current best average reward is 9.0
#
# [Episode 3361]  Actor loss: -12.73955, Critic loss: 3.01958
# [Episode 3362]  Actor loss: -16.89027, Critic loss: 4.95112
# [Episode 3363]  Actor loss: 3.81116, Critic loss: 3.38080
# [Episode 3364]  Actor loss: -14.83539, Critic loss: 3.44348
# [Episode 3365]  Actor loss: -0.88199, Critic loss: 2.23434
# [Episode 3366]  Actor loss: -28.53682, Critic loss: 5.51954
# [Episode 3367]  Actor loss: -8.27227, Critic loss: 4.74230
# [Episode 3368]  Actor loss: -2.75750, Critic loss: 5.38254
# [Episode 3369]  Actor loss: -8.05095, Critic loss: 5.37305
# [Episode 3370]  Actor loss: 3.43460, Critic loss: 3.89108
# Test average reward is -5.0, Current best average reward is 9.0
#
# [Episode 3371]  Actor loss: -10.85033, Critic loss: 6.92031
# [Episode 3372]  Actor loss: -26.53058, Critic loss: 5.16740
# [Episode 3373]  Actor loss: -20.95946, Critic loss: 3.45434
# [Episode 3374]  Actor loss: -20.31849, Critic loss: 3.28721
# [Episode 3375]  Actor loss: -13.46284, Critic loss: 9.93356
# [Episode 3376]  Actor loss: -14.16913, Critic loss: 3.83606
# [Episode 3377]  Actor loss: -0.65926, Critic loss: 2.37135
# [Episode 3378]  Actor loss: -11.07703, Critic loss: 4.65012
# [Episode 3379]  Actor loss: 13.90701, Critic loss: 8.72732
# [Episode 3380]  Actor loss: 18.70004, Critic loss: 12.19746
# Test average reward is -5.0, Current best average reward is 9.0
#
# [Episode 3381]  Actor loss: 13.73630, Critic loss: 8.12070
# [Episode 3382]  Actor loss: -30.18299, Critic loss: 6.20660
# [Episode 3383]  Actor loss: -20.25103, Critic loss: 6.83881
# [Episode 3384]  Actor loss: 4.07745, Critic loss: 16.07387
# [Episode 3385]  Actor loss: -8.85424, Critic loss: 9.55395
# [Episode 3386]  Actor loss: -32.28440, Critic loss: 5.29843
# [Episode 3387]  Actor loss: -2.76979, Critic loss: 4.28977
# [Episode 3388]  Actor loss: -26.22990, Critic loss: 3.48772
# [Episode 3389]  Actor loss: -21.56599, Critic loss: 7.29644
# [Episode 3390]  Actor loss: -20.39170, Critic loss: 8.64446
# Test average reward is -5.0, Current best average reward is 9.0
#
# [Episode 3391]  Actor loss: 9.11394, Critic loss: 4.33118
# [Episode 3392]  Actor loss: 42.27644, Critic loss: 10.01578
# [Episode 3393]  Actor loss: 16.54464, Critic loss: 7.25394
# [Episode 3394]  Actor loss: 35.68309, Critic loss: 4.77676
# [Episode 3395]  Actor loss: 0.67694, Critic loss: 5.81636
# [Episode 3396]  Actor loss: 10.20270, Critic loss: 8.04740
# [Episode 3397]  Actor loss: 4.73803, Critic loss: 3.10167
# [Episode 3398]  Actor loss: -15.44456, Critic loss: 6.44932
# [Episode 3399]  Actor loss: -3.59638, Critic loss: 3.38336
# [Episode 3400]  Actor loss: 1.04799, Critic loss: 3.42800
# Test average reward is -5.0, Current best average reward is 9.0
#
# [Episode 3401]  Actor loss: -20.34534, Critic loss: 4.87787
# [Episode 3402]  Actor loss: -17.69179, Critic loss: 4.50679
# [Episode 3403]  Actor loss: 2.57730, Critic loss: 2.79516
# [Episode 3404]  Actor loss: -22.83503, Critic loss: 3.65412
# [Episode 3405]  Actor loss: -29.51859, Critic loss: 5.87672
# [Episode 3406]  Actor loss: -17.45448, Critic loss: 6.04321
# [Episode 3407]  Actor loss: -28.08012, Critic loss: 4.13680
# [Episode 3408]  Actor loss: -19.80231, Critic loss: 3.46366
# [Episode 3409]  Actor loss: -20.07507, Critic loss: 8.94534
# [Episode 3410]  Actor loss: -40.91795, Critic loss: 4.83824
# Test average reward is -2.0, Current best average reward is 9.0
#
# [Episode 3411]  Actor loss: -14.60114, Critic loss: 4.25953
# [Episode 3412]  Actor loss: -23.67691, Critic loss: 7.13249
# [Episode 3413]  Actor loss: 14.70199, Critic loss: 9.96544
# [Episode 3414]  Actor loss: 0.51425, Critic loss: 7.73888
# [Episode 3415]  Actor loss: -16.50311, Critic loss: 7.47116
# [Episode 3416]  Actor loss: -16.42344, Critic loss: 4.48482
# [Episode 3417]  Actor loss: -35.02824, Critic loss: 4.49124
# [Episode 3418]  Actor loss: -43.30640, Critic loss: 2.99735
# [Episode 3419]  Actor loss: 4.82993, Critic loss: 7.84442
# [Episode 3420]  Actor loss: -18.29360, Critic loss: 13.30382
# Test average reward is -4.0, Current best average reward is 9.0
#
# [Episode 3421]  Actor loss: -19.52269, Critic loss: 9.87311
# [Episode 3422]  Actor loss: -16.37026, Critic loss: 7.40804
# [Episode 3423]  Actor loss: -3.47460, Critic loss: 5.30212
# [Episode 3424]  Actor loss: -1.18312, Critic loss: 14.99960
# [Episode 3425]  Actor loss: 2.95675, Critic loss: 10.97389
# [Episode 3426]  Actor loss: 15.71251, Critic loss: 16.65184
# [Episode 3427]  Actor loss: 2.87748, Critic loss: 10.71283
# [Episode 3428]  Actor loss: -1.32029, Critic loss: 14.99557
# [Episode 3429]  Actor loss: -5.65121, Critic loss: 11.21391
# [Episode 3430]  Actor loss: -26.60622, Critic loss: 10.05815
# Test average reward is -5.0, Current best average reward is 9.0
#
# [Episode 3431]  Actor loss: 9.04821, Critic loss: 9.32230
# [Episode 3432]  Actor loss: 14.65614, Critic loss: 11.34937
# [Episode 3433]  Actor loss: 5.27563, Critic loss: 3.23139
# [Episode 3434]  Actor loss: -14.56877, Critic loss: 4.87772
# [Episode 3435]  Actor loss: -33.60195, Critic loss: 5.24985
# [Episode 3436]  Actor loss: -21.73112, Critic loss: 8.26076
# [Episode 3437]  Actor loss: -48.41822, Critic loss: 6.91569
# [Episode 3438]  Actor loss: -11.63273, Critic loss: 7.93125
# [Episode 3439]  Actor loss: -29.20083, Critic loss: 9.33045
# [Episode 3440]  Actor loss: -24.28412, Critic loss: 7.75608
# Test average reward is -5.0, Current best average reward is 9.0
#
# [Episode 3441]  Actor loss: -29.52868, Critic loss: 5.03922
# [Episode 3442]  Actor loss: 3.37213, Critic loss: 8.93503
# [Episode 3443]  Actor loss: -12.59600, Critic loss: 11.44079
# [Episode 3444]  Actor loss: -27.37893, Critic loss: 13.29577
# [Episode 3445]  Actor loss: -4.98442, Critic loss: 9.42789
# [Episode 3446]  Actor loss: -33.99454, Critic loss: 4.75548
# [Episode 3447]  Actor loss: 3.16916, Critic loss: 25.54741
# [Episode 3448]  Actor loss: 6.25351, Critic loss: 8.97148
# [Episode 3449]  Actor loss: -5.86968, Critic loss: 12.18274
# [Episode 3450]  Actor loss: -10.24299, Critic loss: 8.80511
# Test average reward is 4.0, Current best average reward is 9.0
#
# [Episode 3451]  Actor loss: 14.54964, Critic loss: 15.14263
# [Episode 3452]  Actor loss: -4.64767, Critic loss: 7.81959
# [Episode 3453]  Actor loss: 26.22376, Critic loss: 14.96790
# [Episode 3454]  Actor loss: 2.31549, Critic loss: 7.34860
# [Episode 3455]  Actor loss: -8.41804, Critic loss: 7.71720
# [Episode 3456]  Actor loss: -7.73510, Critic loss: 4.30178
# [Episode 3457]  Actor loss: -11.11815, Critic loss: 13.12118
# [Episode 3458]  Actor loss: -7.80073, Critic loss: 6.16939
# [Episode 3459]  Actor loss: -29.54459, Critic loss: 4.13745
# [Episode 3460]  Actor loss: -15.32218, Critic loss: 5.22966
# Test average reward is 2.0, Current best average reward is 9.0
#
# [Episode 3461]  Actor loss: -26.22132, Critic loss: 5.58095
# [Episode 3462]  Actor loss: -2.37349, Critic loss: 13.30402
# [Episode 3463]  Actor loss: -0.94398, Critic loss: 13.05509
# [Episode 3464]  Actor loss: -1.39637, Critic loss: 17.18141
# [Episode 3465]  Actor loss: 9.90861, Critic loss: 10.18370
# [Episode 3466]  Actor loss: -26.03955, Critic loss: 6.86901
# [Episode 3467]  Actor loss: -17.77550, Critic loss: 8.67743
# [Episode 3468]  Actor loss: 7.36268, Critic loss: 8.39528
# [Episode 3469]  Actor loss: 10.08282, Critic loss: 8.14642
# [Episode 3470]  Actor loss: -10.29444, Critic loss: 6.32366
# Test average reward is -4.0, Current best average reward is 9.0
#
# [Episode 3471]  Actor loss: -22.23129, Critic loss: 8.86829
# [Episode 3472]  Actor loss: -13.52037, Critic loss: 10.41584
# [Episode 3473]  Actor loss: -1.82719, Critic loss: 13.63487
# [Episode 3474]  Actor loss: -14.62379, Critic loss: 10.53786
# [Episode 3475]  Actor loss: -9.97909, Critic loss: 13.63830
# [Episode 3476]  Actor loss: -6.85392, Critic loss: 6.61080
# [Episode 3477]  Actor loss: 11.92052, Critic loss: 11.60282
# [Episode 3478]  Actor loss: 20.84747, Critic loss: 11.28520
# [Episode 3479]  Actor loss: 32.46588, Critic loss: 8.73709
# [Episode 3480]  Actor loss: 25.92420, Critic loss: 9.36560
# Test average reward is -4.0, Current best average reward is 9.0
#
# [Episode 3481]  Actor loss: 11.13779, Critic loss: 8.53996
# [Episode 3482]  Actor loss: -11.06337, Critic loss: 5.83629
# [Episode 3483]  Actor loss: -22.62804, Critic loss: 7.37394
# [Episode 3484]  Actor loss: -17.96080, Critic loss: 11.61934
# [Episode 3485]  Actor loss: -22.81999, Critic loss: 4.54979
# [Episode 3486]  Actor loss: -3.91566, Critic loss: 6.15020
# [Episode 3487]  Actor loss: -6.91452, Critic loss: 6.69382
# [Episode 3488]  Actor loss: -30.66296, Critic loss: 8.19717
# [Episode 3489]  Actor loss: -30.18860, Critic loss: 8.88459
# [Episode 3490]  Actor loss: -16.61962, Critic loss: 10.40238
# Test average reward is 2.0, Current best average reward is 9.0
#
# [Episode 3491]  Actor loss: -29.10554, Critic loss: 10.20834
# [Episode 3492]  Actor loss: -3.02895, Critic loss: 4.74266
# [Episode 3493]  Actor loss: -21.90720, Critic loss: 15.66580
# [Episode 3494]  Actor loss: -35.75171, Critic loss: 7.91084
# [Episode 3495]  Actor loss: -11.53491, Critic loss: 16.08392
# [Episode 3496]  Actor loss: 3.36504, Critic loss: 10.04049
# [Episode 3497]  Actor loss: -35.24714, Critic loss: 4.76139
# [Episode 3498]  Actor loss: -6.12309, Critic loss: 7.62320
# [Episode 3499]  Actor loss: -1.79932, Critic loss: 13.97500
# [Episode 3500]  Actor loss: -25.25090, Critic loss: 12.67314
# Test average reward is 0.0, Current best average reward is 9.0
#
# [Episode 3501]  Actor loss: -26.31362, Critic loss: 5.65938
# [Episode 3502]  Actor loss: -19.53656, Critic loss: 9.19783
# [Episode 3503]  Actor loss: 5.64854, Critic loss: 21.14343
# [Episode 3504]  Actor loss: -16.70170, Critic loss: 9.70975
# [Episode 3505]  Actor loss: -33.25588, Critic loss: 6.25421
# [Episode 3506]  Actor loss: -23.42004, Critic loss: 7.54025
# [Episode 3507]  Actor loss: 9.45650, Critic loss: 10.27246
# [Episode 3508]  Actor loss: 12.86235, Critic loss: 16.21135
# [Episode 3509]  Actor loss: -5.69327, Critic loss: 11.04387
# [Episode 3510]  Actor loss: 3.14240, Critic loss: 10.05722
# Test average reward is -4.0, Current best average reward is 9.0
#
# [Episode 3511]  Actor loss: -17.16158, Critic loss: 9.10447
# [Episode 3512]  Actor loss: -20.71413, Critic loss: 8.41150
# [Episode 3513]  Actor loss: 1.58148, Critic loss: 7.12649
# [Episode 3514]  Actor loss: 8.11609, Critic loss: 16.17970
# [Episode 3515]  Actor loss: 9.44882, Critic loss: 15.10099
# [Episode 3516]  Actor loss: -12.16127, Critic loss: 10.63383
# [Episode 3517]  Actor loss: 30.20457, Critic loss: 10.56384
# [Episode 3518]  Actor loss: -1.81613, Critic loss: 11.31304
# [Episode 3519]  Actor loss: 12.30069, Critic loss: 9.06536
# [Episode 3520]  Actor loss: 5.45300, Critic loss: 7.02952
# Test average reward is -5.0, Current best average reward is 9.0
#
# [Episode 3521]  Actor loss: 8.32263, Critic loss: 8.70152
# [Episode 3522]  Actor loss: 2.16577, Critic loss: 4.87503
# [Episode 3523]  Actor loss: 7.85025, Critic loss: 5.10492
# [Episode 3524]  Actor loss: -5.22253, Critic loss: 7.53356
# [Episode 3525]  Actor loss: -19.78175, Critic loss: 3.89612
# [Episode 3526]  Actor loss: -13.56044, Critic loss: 5.31812
# [Episode 3527]  Actor loss: -8.74774, Critic loss: 10.14353
# [Episode 3528]  Actor loss: -9.38223, Critic loss: 5.89368
# [Episode 3529]  Actor loss: -10.76763, Critic loss: 4.09117
# [Episode 3530]  Actor loss: -5.75033, Critic loss: 6.13423
# Test average reward is -5.0, Current best average reward is 9.0
#
# [Episode 3531]  Actor loss: -24.12846, Critic loss: 6.06751
# [Episode 3532]  Actor loss: -28.83667, Critic loss: 4.81125
# [Episode 3533]  Actor loss: -20.17557, Critic loss: 8.77254
# [Episode 3534]  Actor loss: -25.94216, Critic loss: 7.75292
# [Episode 3535]  Actor loss: -29.38277, Critic loss: 8.53284
# [Episode 3536]  Actor loss: 10.63170, Critic loss: 6.07868
# [Episode 3537]  Actor loss: -43.23009, Critic loss: 4.27362
# [Episode 3538]  Actor loss: 6.05013, Critic loss: 8.93094
# [Episode 3539]  Actor loss: -14.44880, Critic loss: 6.04316
# [Episode 3540]  Actor loss: 3.25644, Critic loss: 9.51634
# Test average reward is 3.0, Current best average reward is 9.0
#
# [Episode 3541]  Actor loss: -23.01147, Critic loss: 7.08118
# [Episode 3542]  Actor loss: -5.31940, Critic loss: 9.58133
# [Episode 3543]  Actor loss: -24.36374, Critic loss: 6.33676
# [Episode 3544]  Actor loss: -3.80195, Critic loss: 7.39240
# [Episode 3545]  Actor loss: -4.46267, Critic loss: 7.31192
# [Episode 3546]  Actor loss: -21.75766, Critic loss: 6.59869
# [Episode 3547]  Actor loss: -8.94680, Critic loss: 7.32752
# [Episode 3548]  Actor loss: -17.14972, Critic loss: 8.29615
# [Episode 3549]  Actor loss: -2.78958, Critic loss: 9.88335
# [Episode 3550]  Actor loss: -13.61739, Critic loss: 10.60148
# Test average reward is -5.0, Current best average reward is 9.0
#
# [Episode 3551]  Actor loss: -27.72918, Critic loss: 8.80051
# [Episode 3552]  Actor loss: -12.53385, Critic loss: 11.53301
# [Episode 3553]  Actor loss: -10.20970, Critic loss: 10.08466
# [Episode 3554]  Actor loss: 9.60675, Critic loss: 7.43881
# [Episode 3555]  Actor loss: -10.80779, Critic loss: 4.76410
# [Episode 3556]  Actor loss: -17.09338, Critic loss: 6.88218
# [Episode 3557]  Actor loss: -10.05599, Critic loss: 9.26502
# [Episode 3558]  Actor loss: -1.24076, Critic loss: 23.84679
# [Episode 3559]  Actor loss: -9.52996, Critic loss: 10.22084
# [Episode 3560]  Actor loss: 20.37320, Critic loss: 12.92888
# Test average reward is -5.0, Current best average reward is 9.0
#
# [Episode 3561]  Actor loss: -0.65018, Critic loss: 8.59950
# [Episode 3562]  Actor loss: -0.67530, Critic loss: 10.65372
# [Episode 3563]  Actor loss: -35.80777, Critic loss: 6.26907
# [Episode 3564]  Actor loss: -16.69936, Critic loss: 7.13945
# [Episode 3565]  Actor loss: -19.00754, Critic loss: 6.46196
# [Episode 3566]  Actor loss: -28.26593, Critic loss: 7.55152
# [Episode 3567]  Actor loss: -27.45257, Critic loss: 4.36437
# [Episode 3568]  Actor loss: -12.86625, Critic loss: 6.33347
# [Episode 3569]  Actor loss: -14.46090, Critic loss: 9.35943
# [Episode 3570]  Actor loss: -9.53128, Critic loss: 5.56213
# Test average reward is -5.0, Current best average reward is 9.0
#
# [Episode 3571]  Actor loss: 5.38752, Critic loss: 6.25601
# [Episode 3572]  Actor loss: -19.35686, Critic loss: 4.43346
# [Episode 3573]  Actor loss: -10.66359, Critic loss: 8.35224
# [Episode 3574]  Actor loss: -2.83563, Critic loss: 8.47762
# [Episode 3575]  Actor loss: 3.95309, Critic loss: 20.93681
# [Episode 3576]  Actor loss: -0.26053, Critic loss: 9.72079
# [Episode 3577]  Actor loss: -1.70193, Critic loss: 12.80787
# [Episode 3578]  Actor loss: -24.97458, Critic loss: 4.59305
# [Episode 3579]  Actor loss: -23.96868, Critic loss: 7.37965
# [Episode 3580]  Actor loss: -17.10128, Critic loss: 11.46059
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test average reward is 13.0, Current best average reward is 9.0

# %% [markdown]
# # Report:
#
# In this implementation, the design of the Actor-Critic network effectively integrates convolutional neural network (CNN) feature extraction with PPO (Proximal Policy Optimization) strategy optimization. In the network architecture, high-level features are extracted from input data through multiple convolutional layers and nonlinear activation functions. These features are then further mapped using fully connected layers, finally splitting into two branches: the **Actor** outputs the action probability distribution, while the **Critic** outputs the state value function. This design effectively separates strategy learning (Actor) from value evaluation (Critic), allowing the network to learn both action policies and state values simultaneously, thereby improving learning efficiency.
#
# The PPO update process utilizes the **importance sampling ratio** to measure the difference between the new and old policies. Through a "clipping" operation, the update magnitude of the policy is controlled. Specifically, with `tf.clip_by_value`, the ratio \( r \) is constrained between \( 1 - \epsilon \) and \( 1 + \epsilon \), preventing the policy from changing too drastically in a single update. This is the core idea of PPO, which stabilizes the training process and accelerates convergence.
#
# Regarding the loss function, the Actor loss incorporates a combination of policy loss and weighted policy entropy. The policy entropy encourages exploratory behavior, preventing the policy from falling into local optima. The Critic loss, on the other hand, is based on the **Mean Squared Error (MSE)**, measuring the difference between the estimated value function and the actual return. This helps guide the value network to learn more accurate evaluations.
#
# I used the CPU to run a total of 3580 episodes to reach the 10-point threshold, which took about 20 hours.
